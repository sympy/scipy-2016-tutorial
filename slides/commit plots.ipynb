# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
data = array([int(l.split()[0]) for l in open("sympy-all.txt").readlines()])
data = data / float(data[0])
plot(data, label="all time")
data2 = array([int(l.split()[0]) for l in open("sympy-year.txt").readlines()])
data2 = data2 / float(data2[0])
plot(data2, label="last year")
legend()
xlim([0, 50]);

# %%
data = array([int(l.split()[0]) for l in open("sympy-all.txt").readlines()])
#data = data / float(data[0])
semilogy(data, label="all time")
data2 = array([int(l.split()[0]) for l in open("sympy-year.txt").readlines()])
#data2 = data2 / float(data2[0])
semilogy(data2, label="last year")
legend()
#xlim([0, 50]);
